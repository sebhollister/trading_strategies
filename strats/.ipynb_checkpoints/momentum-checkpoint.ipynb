# %% [markdown]
# ### MOMENTUM STRAT

# %%
import sys
sys.path.append('../')
from feature_ext import price_momentum as pm
from models import votingClassifierM as vc
from list_generators import sp_indexes as sp

# %%
X, y, df = pm.extract_featuresets("MMM")
# Out:
# Data spread:  Counter({'1': 100, '-1': 89, '0': 64})

# %%
vc.train_test(X, y, "MMM")
# Out:
# accuracy: 0.34375
# predicted class counts: Counter({-1: 30, 1: 23, 0: 11})
# (-1, 0.34375)

# %%
sp500 = sp.get_sp500()
sp500
long, short = vc.test_all(sp500)
# Out:
# Data spread:  Counter({'1': 100, '-1': 89, '0': 64})
# {count} / 500 trained
# accuracy: 0.28125
# predicted class counts: Counter({-1: 41, 0: 12, 1: 11})
# MMM accuracy: (0, 0.28125). Average accuracy:0.28125
# Data spread:  Counter({'1': 103, '0': 82, '-1': 68})
# accuracy: 0.3125
# predicted class counts: Counter({0: 26, -1: 22, 1: 16})
# ABT accuracy: (0, 0.3125). Average accuracy:0.296875
# Data spread:  Counter({'1': 105, '-1': 85, '0': 63})
# accuracy: 0.359375
# predicted class counts: Counter({-1: 30, 1: 24, 0: 10})
# ABBV accuracy: (1, 0.359375). Average accuracy:0.3177083333333333
# Data spread:  Counter({'-1': 116, '1': 94, '0': 43})
# accuracy: 0.484375
# predicted class counts: Counter({-1: 51, 1: 12, 0: 1})
# ABMD accuracy: (1, 0.484375). Average accuracy:0.359375
# Data spread:  Counter({'1': 124, '0': 89, '-1': 40})
# accuracy: 0.421875
# predicted class counts: Counter({1: 41, 0: 21, -1: 2})
# ACN accuracy: (1, 0.421875). Average accuracy:0.371875
# Data spread:  Counter({'1': 111, '-1': 84, '0': 58})
# accuracy: 0.453125
# predicted class counts: Counter({1: 36, -1: 23, 0: 5})
# ATVI accuracy: (1, 0.453125). Average accuracy:0.3854166666666667
# Data spread:  Counter({'1': 126, '-1': 66, '0': 61})
# accuracy: 0.4375
# predicted class counts: Counter({1: 48, -1: 13, 0: 3})
# ADBE accuracy: (0, 0.4375). Average accuracy:0.39285714285714285
# Data spread:  Counter({'1': 135, '-1': 77, '0': 41})
# accuracy: 0.484375
# predicted class counts: Counter({1: 48, -1: 14, 0: 2})
# AMD accuracy: (1, 0.484375). Average accuracy:0.404296875
# Data spread:  Counter({'1': 104, '-1': 97, '0': 52})
# accuracy: 0.296875
# predicted class counts: Counter({-1: 32, 1: 25, 0: 7})
# AAP accuracy: (1, 0.296875). Average accuracy:0.3923611111111111
# Data spread:  Counter({'1': 124, '0': 70, '-1': 59})
# accuracy: 0.375
# predicted class counts: Counter({1: 35, 0: 16, -1: 13})
# AES accuracy: (-1, 0.375). Average accuracy:0.390625
# Data spread:  Counter({'0': 121, '1': 86, '-1': 46})
# {count} / 500 trained
# accuracy: 0.515625
# predicted class counts: Counter({0: 54, 1: 7, -1: 3})
# AFL accuracy: (0, 0.515625). Average accuracy:0.40198863636363635
# Data spread:  Counter({'1': 128, '-1': 66, '0': 59})
# accuracy: 0.40625
# predicted class counts: Counter({1: 48, -1: 12, 0: 4})
# A accuracy: (-1, 0.40625). Average accuracy:0.40234375
# Data spread:  Counter({'1': 122, '0': 77, '-1': 54})
# accuracy: 0.390625
# predicted class counts: Counter({1: 37, 0: 20, -1: 7})
# APD accuracy: (0, 0.390625). Average accuracy:0.4014423076923077
# Data spread:  Counter({'1': 123, '0': 66, '-1': 64})
# accuracy: 0.515625
# predicted class counts: Counter({1: 47, -1: 9, 0: 8})
# AKAM accuracy: (1, 0.515625). Average accuracy:0.4095982142857143
# Data spread:  Counter({'1': 106, '-1': 88, '0': 59})
# accuracy: 0.3125
# predicted class counts: Counter({-1: 37, 1: 20, 0: 7})
# ALK accuracy: (1, 0.3125). Average accuracy:0.403125
# Data spread:  Counter({'-1': 105, '1': 101, '0': 47})
# accuracy: 0.390625
# predicted class counts: Counter({-1: 40, 1: 21, 0: 3})
# ALB accuracy: (-1, 0.390625). Average accuracy:0.40234375
# Data spread:  Counter({'1': 116, '0': 95, '-1': 42})
# accuracy: 0.421875
# predicted class counts: Counter({0: 30, 1: 29, -1: 5})
# ARE accuracy: (0, 0.421875). Average accuracy:0.40349264705882354
# Data spread:  Counter({'1': 106, '-1': 100, '0': 47})
# accuracy: 0.421875
# predicted class counts: Counter({-1: 46, 1: 16, 0: 2})
# ALXN accuracy: (-1, 0.421875). Average accuracy:0.4045138888888889
# Data spread:  Counter({'1': 132, '-1': 80, '0': 41})
# accuracy: 0.46875
# predicted class counts: Counter({1: 43, -1: 20, 0: 1})
# ALGN accuracy: (1, 0.46875). Average accuracy:0.40789473684210525
# Data spread:  Counter({'1': 121, '0': 77, '-1': 55})
# accuracy: 0.40625
# predicted class counts: Counter({1: 30, 0: 28, -1: 6})
# ALLE accuracy: (1, 0.40625). Average accuracy:0.4078125
# Data spread:  Counter({'1': 108, '0': 77, '-1': 68})
# {count} / 500 trained
# accuracy: 0.390625
# predicted class counts: Counter({1: 30, 0: 26, -1: 8})
# AGN accuracy: (-1, 0.390625). Average accuracy:0.4069940476190476
# Data spread:  Counter({'-1': 116, '1': 96, '0': 41})
# accuracy: 0.53125
# predicted class counts: Counter({-1: 41, 1: 20, 0: 3})
# ADS accuracy: (-1, 0.53125). Average accuracy:0.41264204545454547
# Data spread:  Counter({'0': 109, '1': 107, '-1': 37})
# accuracy: 0.328125
# predicted class counts: Counter({0: 42, 1: 21, -1: 1})
# LNT accuracy: (0, 0.328125). Average accuracy:0.40896739130434784
# Data spread:  Counter({'1': 113, '0': 94, '-1': 46})
# accuracy: 0.359375
# predicted class counts: Counter({0: 35, 1: 24, -1: 5})
# ALL accuracy: (0, 0.359375). Average accuracy:0.4069010416666667
# Data spread:  Counter({'1': 116, '0': 81, '-1': 56})
# accuracy: 0.484375
# predicted class counts: Counter({0: 32, 1: 30, -1: 2})
# GOOGL accuracy: (0, 0.484375). Average accuracy:0.41
# Data spread:  Counter({'1': 116, '0': 80, '-1': 57})
# accuracy: 0.34375
# predicted class counts: Counter({1: 42, 0: 13, -1: 9})
# GOOG accuracy: (0, 0.34375). Average accuracy:0.4074519230769231
# Data spread:  Counter({'1': 108, '-1': 78, '0': 67})
# accuracy: 0.421875
# predicted class counts: Counter({1: 30, -1: 21, 0: 13})
# MO accuracy: (0, 0.421875). Average accuracy:0.4079861111111111
# Data spread:  Counter({'1': 112, '-1': 79, '0': 62})
# accuracy: 0.46875
# predicted class counts: Counter({1: 46, -1: 13, 0: 5})
# AMZN accuracy: (1, 0.46875). Average accuracy:0.41015625
# Data spread:  Counter({'1': 97, '0': 92, '-1': 64})
# accuracy: 0.3125
# predicted class counts: Counter({1: 30, 0: 22, -1: 12})
# AMCR accuracy: (0, 0.3125). Average accuracy:0.4067887931034483
# Data spread:  Counter({'1': 101, '0': 95, '-1': 57})
# accuracy: 0.296875
# predicted class counts: Counter({0: 37, -1: 19, 1: 8})
# AEE accuracy: (0, 0.296875). Average accuracy:0.403125
# Data spread:  Counter({'-1': 112, '1': 99, '0': 42})
# {count} / 500 trained
# accuracy: 0.515625
# predicted class counts: Counter({-1: 50, 1: 14})
# AAL accuracy: (-1, 0.515625). Average accuracy:0.4067540322580645
# Data spread:  Counter({'1': 112, '0': 98, '-1': 43})
# accuracy: 0.3125
# predicted class counts: Counter({1: 33, 0: 31})
# AEP accuracy: (0, 0.3125). Average accuracy:0.40380859375
# Data spread:  Counter({'1': 112, '0': 85, '-1': 56})
# accuracy: 0.375
# predicted class counts: Counter({1: 37, 0: 15, -1: 12})
# AXP accuracy: (0, 0.375). Average accuracy:0.4029356060606061
# Data spread:  Counter({'1': 111, '-1': 79, '0': 63})
# accuracy: 0.3125
# predicted class counts: Counter({1: 33, -1: 21, 0: 10})
# AIG accuracy: (1, 0.3125). Average accuracy:0.40027573529411764
# Data spread:  Counter({'1': 134, '0': 69, '-1': 50})
# accuracy: 0.34375
# predicted class counts: Counter({1: 45, 0: 11, -1: 8})
# AMT accuracy: (1, 0.34375). Average accuracy:0.3986607142857143
# Data spread:  Counter({'1': 119, '0': 87, '-1': 47})
# accuracy: 0.375
# predicted class counts: Counter({1: 29, 0: 21, -1: 14})
# AWK accuracy: (1, 0.375). Average accuracy:0.3980034722222222
# Data spread:  Counter({'1': 123, '0': 72, '-1': 58})
# accuracy: 0.40625
# predicted class counts: Counter({1: 42, 0: 14, -1: 8})
# AMP accuracy: (1, 0.40625). Average accuracy:0.39822635135135137
# Data spread:  Counter({'1': 108, '-1': 92, '0': 53})
# accuracy: 0.390625
# predicted class counts: Counter({1: 31, -1: 26, 0: 7})
# ABC accuracy: (0, 0.390625). Average accuracy:0.3980263157894737
# Data spread:  Counter({'1': 107, '0': 101, '-1': 45})
# accuracy: 0.484375
# predicted class counts: Counter({1: 29, 0: 29, -1: 6})
# AME accuracy: (1, 0.484375). Average accuracy:0.40024038461538464
# Data spread:  Counter({'1': 113, '0': 70, '-1': 70})
# accuracy: 0.421875
# predicted class counts: Counter({1: 40, 0: 13, -1: 11})
# AMGN accuracy: (1, 0.421875). Average accuracy:0.40078125
# Data spread:  Counter({'1': 123, '0': 71, '-1': 59})
# {count} / 500 trained
# accuracy: 0.46875
# predicted class counts: Counter({1: 41, -1: 14, 0: 9})
# APH accuracy: (1, 0.46875). Average accuracy:0.4024390243902439
# Data spread:  Counter({'1': 130, '-1': 70, '0': 53})
# accuracy: 0.40625
# predicted class counts: Counter({1: 53, -1: 10, 0: 1})
# ADI accuracy: (1, 0.40625). Average accuracy:0.4025297619047619
# Data spread:  Counter({'1': 131, '0': 70, '-1': 52})
# accuracy: 0.40625
# predicted class counts: Counter({1: 46, 0: 13, -1: 5})
# ANSS accuracy: (0, 0.40625). Average accuracy:0.40261627906976744
# Data spread:  Counter({'1': 112, '-1': 87, '0': 54})
# accuracy: 0.34375
# predicted class counts: Counter({-1: 28, 1: 28, 0: 8})
# ANTM accuracy: (1, 0.34375). Average accuracy:0.4012784090909091
# Data spread:  Counter({'1': 117, '0': 91, '-1': 45})
# accuracy: 0.359375
# predicted class counts: Counter({1: 36, 0: 25, -1: 3})
# AON accuracy: (1, 0.359375). Average accuracy:0.40034722222222224
# Data spread:  Counter({'1': 115, '-1': 90, '0': 48})
# accuracy: 0.4375
# predicted class counts: Counter({-1: 30, 1: 26, 0: 8})
# AOS accuracy: (-1, 0.4375). Average accuracy:0.40115489130434784
# Data spread:  Counter({'-1': 114, '1': 111, '0': 28})
# accuracy: 0.421875
# predicted class counts: Counter({-1: 42, 1: 22})
# APA accuracy: (1, 0.421875). Average accuracy:0.4015957446808511
# Data spread:  Counter({'0': 108, '1': 95, '-1': 50})
# accuracy: 0.375
# predicted class counts: Counter({0: 57, 1: 7})
# AIV accuracy: (0, 0.375). Average accuracy:0.4010416666666667
# Data spread:  Counter({'1': 157, '0': 56, '-1': 40})
# accuracy: 0.5625
# predicted class counts: Counter({1: 53, 0: 7, -1: 4})
# AAPL accuracy: (1, 0.5625). Average accuracy:0.40433673469387754
# Data spread:  Counter({'1': 130, '-1': 70, '0': 53})
# accuracy: 0.515625
# predicted class counts: Counter({1: 48, -1: 12, 0: 4})
# AMAT accuracy: (1, 0.515625). Average accuracy:0.4065625
# Data spread:  Counter({'1': 123, '-1': 87, '0': 43})
# {count} / 500 trained
# accuracy: 0.390625
# predicted class counts: Counter({1: 43, -1: 15, 0: 6})
# APTV accuracy: (1, 0.390625). Average accuracy:0.40625
# Data spread:  Counter({'1': 105, '0': 81, '-1': 67})
# accuracy: 0.28125
# predicted class counts: Counter({0: 27, 1: 19, -1: 18})
# ADM accuracy: (0, 0.28125). Average accuracy:0.40384615384615385
# Data spread:  Counter({'1': 133, '-1': 69, '0': 51})
# accuracy: 0.453125
# predicted class counts: Counter({1: 42, -1: 18, 0: 4})
# ARNC accuracy: (1, 0.453125). Average accuracy:0.4047759433962264
# Data spread:  Counter({'1': 127, '-1': 88, '0': 38})
# accuracy: 0.515625
# predicted class counts: Counter({1: 40, -1: 20, 0: 4})
# ANET accuracy: (-1, 0.515625). Average accuracy:0.4068287037037037
# Data spread:  Counter({'0': 105, '1': 103, '-1': 45})
# accuracy: 0.453125
# predicted class counts: Counter({0: 40, 1: 22, -1: 2})
# AJG accuracy: (1, 0.453125). Average accuracy:0.40767045454545453
# Data spread:  Counter({'1': 115, '0': 87, '-1': 51})
# accuracy: 0.359375
# predicted class counts: Counter({0: 31, 1: 28, -1: 5})
# AIZ accuracy: (1, 0.359375). Average accuracy:0.4068080357142857
# Data spread:  Counter({'0': 102, '1': 100, '-1': 51})
# accuracy: 0.375
# predicted class counts: Counter({0: 42, 1: 18, -1: 4})
# ATO accuracy: (0, 0.375). Average accuracy:0.40625
# Data spread:  Counter({'1': 113, '0': 84, '-1': 56})
# accuracy: 0.46875
# predicted class counts: Counter({1: 31, 0: 25, -1: 8})
# T accuracy: (0, 0.46875). Average accuracy:0.4073275862068966
# Data spread:  Counter({'1': 126, '-1': 73, '0': 54})
# accuracy: 0.484375
# predicted class counts: Counter({1: 39, -1: 21, 0: 4})
# ADSK accuracy: (-1, 0.484375). Average accuracy:0.4086334745762712
# Data spread:  Counter({'1': 109, '0': 92, '-1': 52})
# accuracy: 0.421875
# predicted class counts: Counter({1: 32, 0: 22, -1: 10})
# ADP accuracy: (-1, 0.421875). Average accuracy:0.4088541666666667
# Data spread:  Counter({'1': 121, '0': 67, '-1': 65})
# {count} / 500 trained
# accuracy: 0.296875
# predicted class counts: Counter({1: 37, -1: 22, 0: 5})
# AZO accuracy: (-1, 0.296875). Average accuracy:0.40701844262295084
# Data spread:  Counter({'0': 103, '1': 99, '-1': 51})
# accuracy: 0.421875
# predicted class counts: Counter({0: 41, 1: 20, -1: 3})
# AVB accuracy: (0, 0.421875). Average accuracy:0.40725806451612906
# Data spread:  Counter({'1': 121, '-1': 67, '0': 65})
# accuracy: 0.421875
# predicted class counts: Counter({1: 38, -1: 18, 0: 8})
# AVY accuracy: (-1, 0.421875). Average accuracy:0.40749007936507936
# Data spread:  Counter({'1': 109, '-1': 88, '0': 56})
# accuracy: 0.25
# predicted class counts: Counter({-1: 38, 1: 21, 0: 5})
# BKR accuracy: (-1, 0.25). Average accuracy:0.405029296875
# Data spread:  Counter({'1': 128, '0': 69, '-1': 56})
# accuracy: 0.4375
# predicted class counts: Counter({1: 33, -1: 22, 0: 9})
# BLL accuracy: (-1, 0.4375). Average accuracy:0.40552884615384616
# Data spread:  Counter({'1': 117, '-1': 71, '0': 65})
# accuracy: 0.375
# predicted class counts: Counter({1: 41, -1: 13, 0: 10})
# BAC accuracy: (0, 0.375). Average accuracy:0.4050662878787879
# Data spread:  Counter({'1': 99, '-1': 91, '0': 63})
# accuracy: 0.40625
# predicted class counts: Counter({-1: 48, 1: 9, 0: 7})
# BK accuracy: (-1, 0.40625). Average accuracy:0.4050839552238806
# Data spread:  Counter({'1': 115, '0': 92, '-1': 46})
# accuracy: 0.5
# predicted class counts: Counter({1: 28, 0: 28, -1: 8})
# BAX accuracy: (0, 0.5). Average accuracy:0.4064797794117647
# Data spread:  Counter({'1': 110, '0': 80, '-1': 63})
# accuracy: 0.3125
# predicted class counts: Counter({0: 25, 1: 22, -1: 17})
# BDX accuracy: (1, 0.3125). Average accuracy:0.4051177536231884
# Data spread:  Counter({'1': 131, '0': 61, '-1': 61})
# {count} / 500 trained
# accuracy: 0.40625
# predicted class counts: Counter({1: 47, 0: 9, -1: 8})
# BBY accuracy: (1, 0.40625). Average accuracy:0.40513392857142855
# Data spread:  Counter({'1': 98, '-1': 95, '0': 60})
# accuracy: 0.375
# predicted class counts: Counter({-1: 37, 1: 24, 0: 3})
# BIIB accuracy: (-1, 0.375). Average accuracy:0.4047095070422535
# Data spread:  Counter({'1': 127, '0': 63, '-1': 63})
# accuracy: 0.34375
# predicted class counts: Counter({1: 49, -1: 10, 0: 5})
# BLK accuracy: (1, 0.34375). Average accuracy:0.4038628472222222
# Data spread:  Counter({'1': 104, '-1': 88, '0': 61})
# accuracy: 0.3125
# predicted class counts: Counter({-1: 45, 0: 11, 1: 8})
# BA accuracy: (-1, 0.3125). Average accuracy:0.402611301369863
# Data spread:  Counter({'1': 129, '-1': 71, '0': 53})
# accuracy: 0.390625
# predicted class counts: Counter({1: 38, 0: 14, -1: 12})
# BKNG accuracy: (-1, 0.390625). Average accuracy:0.40244932432432434
# Data spread:  Counter({'1': 113, '-1': 108, '0': 32})
# accuracy: 0.5
# predicted class counts: Counter({1: 33, -1: 30, 0: 1})
# BWA accuracy: (-1, 0.5). Average accuracy:0.40375
# Data spread:  Counter({'1': 98, '0': 96, '-1': 59})
# accuracy: 0.390625
# predicted class counts: Counter({0: 31, 1: 29, -1: 4})
# BXP accuracy: (1, 0.390625). Average accuracy:0.4035773026315789
# Data spread:  Counter({'1': 114, '0': 79, '-1': 60})
# accuracy: 0.296875
# predicted class counts: Counter({1: 35, 0: 15, -1: 14})
# BSX accuracy: (-1, 0.296875). Average accuracy:0.40219155844155846
# Data spread:  Counter({'1': 116, '-1': 72, '0': 65})
# accuracy: 0.390625
# predicted class counts: Counter({1: 27, -1: 26, 0: 11})
# BMY accuracy: (-1, 0.390625). Average accuracy:0.4020432692307692
# Data spread:  Counter({'1': 123, '-1': 77, '0': 53})
# accuracy: 0.34375
# predicted class counts: Counter({1: 34, -1: 28, 0: 2})
# AVGO accuracy: (-1, 0.34375). Average accuracy:0.40130537974683544
# Data spread:  Counter({'1': 113, '0': 79, '-1': 61})
# {count} / 500 trained
# accuracy: 0.296875
# predicted class counts: Counter({1: 31, 0: 22, -1: 11})
# BR accuracy: (0, 0.296875). Average accuracy:0.4
# Data spread:  Counter({'1': 110, '-1': 78, '0': 65})
# accuracy: 0.40625
# predicted class counts: Counter({1: 35, -1: 16, 0: 13})
# CHRW accuracy: (0, 0.40625). Average accuracy:0.40007716049382713
# Data spread:  Counter({'-1': 106, '1': 91, '0': 56})
# accuracy: 0.296875
# predicted class counts: Counter({-1: 43, 1: 18, 0: 3})
# COG accuracy: (1, 0.296875). Average accuracy:0.3988185975609756
# Data spread:  Counter({'1': 129, '0': 71, '-1': 53})
# accuracy: 0.421875
# predicted class counts: Counter({1: 37, -1: 17, 0: 10})
# CDNS accuracy: (1, 0.421875). Average accuracy:0.3990963855421687
# Data spread:  Counter({'1': 103, '0': 84, '-1': 66})
# accuracy: 0.328125
# predicted class counts: Counter({1: 23, 0: 21, -1: 20})
# CPB accuracy: (-1, 0.328125). Average accuracy:0.3982514880952381
# Data spread:  Counter({'1': 116, '0': 71, '-1': 66})
# accuracy: 0.4375
# predicted class counts: Counter({1: 37, -1: 14, 0: 13})
# COF accuracy: (1, 0.4375). Average accuracy:0.3987132352941177
# Data spread:  Counter({'1': 106, '-1': 105, '0': 42})
# accuracy: 0.390625
# predicted class counts: Counter({-1: 33, 1: 26, 0: 5})
# CPRI accuracy: (-1, 0.390625). Average accuracy:0.39861918604651164
# Data spread:  Counter({'1': 108, '-1': 97, '0': 48})
# accuracy: 0.484375
# predicted class counts: Counter({-1: 41, 1: 21, 0: 2})
# CAH accuracy: (1, 0.484375). Average accuracy:0.39960488505747127
# Data spread:  Counter({'1': 111, '-1': 71, '0': 71})
# accuracy: 0.390625
# predicted class counts: Counter({1: 42, 0: 14, -1: 8})
# KMX accuracy: (1, 0.390625). Average accuracy:0.3995028409090909
# Data spread:  Counter({'1': 107, '-1': 83, '0': 63})
# {count} / 500 trained
# accuracy: 0.421875
# predicted class counts: Counter({1: 37, -1: 19, 0: 8})
# CCL accuracy: (-1, 0.421875). Average accuracy:0.39975421348314605
# Data spread:  Counter({'1': 107, '-1': 90, '0': 56})
# accuracy: 0.359375
# predicted class counts: Counter({1: 29, -1: 27, 0: 8})
# CAT accuracy: (1, 0.359375). Average accuracy:0.3993055555555556
# Data spread:  Counter({'1': 100, '0': 85, '-1': 68})
# accuracy: 0.375
# predicted class counts: Counter({0: 28, -1: 20, 1: 16})
# CBOE accuracy: (0, 0.375). Average accuracy:0.39903846153846156
# Data spread:  Counter({'1': 125, '0': 65, '-1': 63})
# accuracy: 0.421875
# predicted class counts: Counter({1: 36, -1: 16, 0: 12})
# CBRE accuracy: (1, 0.421875). Average accuracy:0.3992866847826087
# Data spread:  Counter({'1': 127, '0': 78, '-1': 48})
# accuracy: 0.34375
# predicted class counts: Counter({1: 39, 0: 17, -1: 8})
# CDW accuracy: (1, 0.34375). Average accuracy:0.39868951612903225
# Data spread:  Counter({'1': 105, '-1': 77, '0': 71})
# accuracy: 0.421875
# predicted class counts: Counter({1: 34, -1: 23, 0: 7})
# CE accuracy: (-1, 0.421875). Average accuracy:0.39893617021276595
# Data spread:  Counter({'1': 115, '-1': 92, '0': 46})
# accuracy: 0.359375
# predicted class counts: Counter({-1: 30, 1: 29, 0: 5})
# CNC accuracy: (1, 0.359375). Average accuracy:0.3985197368421053
# Data spread:  Counter({'1': 95, '0': 85, '-1': 73})
# accuracy: 0.296875
# predicted class counts: Counter({0: 30, -1: 25, 1: 9})
# CNP accuracy: (0, 0.296875). Average accuracy:0.3974609375
# Data spread:  Counter({'-1': 110, '1': 94, '0': 49})
# accuracy: 0.328125
# predicted class counts: Counter({-1: 51, 1: 9, 0: 4})
# CTL accuracy: (1, 0.328125). Average accuracy:0.39674613402061853
# Data spread:  Counter({'1': 109, '0': 88, '-1': 56})
# accuracy: 0.4375
# predicted class counts: Counter({0: 33, 1: 24, -1: 7})
# CERN accuracy: (1, 0.4375). Average accuracy:0.3971619897959184
# Data spread:  Counter({'1': 105, '-1': 99, '0': 49})
# {count} / 500 trained
# accuracy: 0.34375
# predicted class counts: Counter({-1: 45, 1: 16, 0: 3})
# CF accuracy: (-1, 0.34375). Average accuracy:0.39662247474747475
# Data spread:  Counter({'1': 106, '-1': 92, '0': 55})
# accuracy: 0.3125
# predicted class counts: Counter({-1: 34, 1: 26, 0: 4})
# SCHW accuracy: (-1, 0.3125). Average accuracy:0.39578125
# Data spread:  Counter({'1': 124, '0': 70, '-1': 59})
# accuracy: 0.421875
# predicted class counts: Counter({1: 44, 0: 12, -1: 8})
# CHTR accuracy: (1, 0.421875). Average accuracy:0.39603960396039606
# Data spread:  Counter({'1': 98, '0': 96, '-1': 59})
# accuracy: 0.359375
# predicted class counts: Counter({0: 30, 1: 22, -1: 12})
# CVX accuracy: (0, 0.359375). Average accuracy:0.39568014705882354
# Data spread:  Counter({'1': 123, '0': 80, '-1': 50})
# accuracy: 0.421875
# predicted class counts: Counter({1: 37, 0: 17, -1: 10})
# CMG accuracy: (0, 0.421875). Average accuracy:0.39593446601941745
# Data spread:  Counter({'0': 115, '1': 92, '-1': 46})
# accuracy: 0.453125
# predicted class counts: Counter({0: 48, 1: 13, -1: 3})
# CB accuracy: (0, 0.453125). Average accuracy:0.396484375
# Data spread:  Counter({'1': 106, '0': 92, '-1': 55})
# accuracy: 0.484375
# predicted class counts: Counter({0: 36, 1: 21, -1: 7})
# CHD accuracy: (1, 0.484375). Average accuracy:0.39732142857142855
# Data spread:  Counter({'1': 110, '-1': 97, '0': 46})
# accuracy: 0.296875
# predicted class counts: Counter({-1: 48, 1: 16})
# CI accuracy: (-1, 0.296875). Average accuracy:0.396373820754717
# Data spread:  Counter({'-1': 109, '1': 96, '0': 48})
# accuracy: 0.4375
# predicted class counts: Counter({-1: 49, 1: 9, 0: 6})
# XEC accuracy: (0, 0.4375). Average accuracy:0.39675817757009346
# Data spread:  Counter({'1': 107, '0': 100, '-1': 46})
# accuracy: 0.4375
# predicted class counts: Counter({0: 44, 1: 18, -1: 2})
# CINF accuracy: (0, 0.4375). Average accuracy:0.3971354166666667
# Data spread:  Counter({'1': 130, '0': 71, '-1': 52})
# {count} / 500 trained
# accuracy: 0.484375
# predicted class counts: Counter({1: 45, 0: 12, -1: 7})
# CTAS accuracy: (0, 0.484375). Average accuracy:0.39793577981651373
# Data spread:  Counter({'1': 116, '-1': 76, '0': 61})
# accuracy: 0.390625
# predicted class counts: Counter({1: 32, -1: 17, 0: 15})
# CSCO accuracy: (0, 0.390625). Average accuracy:0.3978693181818182
# Data spread:  Counter({'1': 126, '-1': 67, '0': 60})
# accuracy: 0.453125
# predicted class counts: Counter({1: 39, 0: 14, -1: 11})
# C accuracy: (1, 0.453125). Average accuracy:0.39836711711711714
# Data spread:  Counter({'1': 118, '-1': 70, '0': 65})
# accuracy: 0.421875
# predicted class counts: Counter({1: 35, 0: 16, -1: 13})
# CFG accuracy: (1, 0.421875). Average accuracy:0.39857700892857145
# Data spread:  Counter({'1': 96, '0': 93, '-1': 64})
# accuracy: 0.375
# predicted class counts: Counter({0: 34, 1: 20, -1: 10})
# CTXS accuracy: (0, 0.375). Average accuracy:0.3983683628318584
# Data spread:  Counter({'0': 103, '1': 81, '-1': 69})
# accuracy: 0.453125
# predicted class counts: Counter({0: 49, -1: 8, 1: 7})
# CLX accuracy: (0, 0.453125). Average accuracy:0.3988486842105263
# Data spread:  Counter({'1': 103, '-1': 79, '0': 71})
# accuracy: 0.28125
# predicted class counts: Counter({-1: 33, 1: 18, 0: 13})
# CME accuracy: (1, 0.28125). Average accuracy:0.3978260869565217
# Data spread:  Counter({'1': 109, '0': 104, '-1': 40})
# accuracy: 0.421875
# predicted class counts: Counter({0: 37, 1: 26, -1: 1})
# CMS accuracy: (0, 0.421875). Average accuracy:0.3980334051724138
# Data spread:  Counter({'0': 119, '1': 97, '-1': 37})
# accuracy: 0.484375
# predicted class counts: Counter({0: 53, 1: 11})
# KO accuracy: (0, 0.484375). Average accuracy:0.39877136752136755
# Data spread:  Counter({'1': 97, '0': 82, '-1': 74})
# accuracy: 0.234375
# predicted class counts: Counter({0: 40, -1: 13, 1: 11})
# CTSH accuracy: (0, 0.234375). Average accuracy:0.3973781779661017
# Data spread:  Counter({'1': 100, '0': 96, '-1': 57})
# {count} / 500 trained
# accuracy: 0.296875
# predicted class counts: Counter({0: 43, 1: 11, -1: 10})
# CL accuracy: (1, 0.296875). Average accuracy:0.39653361344537813
# Data spread:  Counter({'1': 109, '0': 82, '-1': 62})
# accuracy: 0.46875
# predicted class counts: Counter({1: 41, 0: 15, -1: 8})
# CMCSA accuracy: (1, 0.46875). Average accuracy:0.3971354166666667
# Data spread:  Counter({'1': 98, '-1': 95, '0': 60})
# accuracy: 0.328125
# predicted class counts: Counter({-1: 44, 1: 15, 0: 5})
# CMA accuracy: (-1, 0.328125). Average accuracy:0.3965650826446281
# Data spread:  Counter({'1': 108, '-1': 80, '0': 65})
# accuracy: 0.328125
# predicted class counts: Counter({1: 25, -1: 23, 0: 16})
# CAG accuracy: (0, 0.328125). Average accuracy:0.39600409836065575
# Data spread:  Counter({'1': 107, '-1': 93, '0': 53})
# accuracy: 0.328125
# predicted class counts: Counter({-1: 30, 1: 25, 0: 9})
# CXO accuracy: (1, 0.328125). Average accuracy:0.3954522357723577
# Data spread:  Counter({'1': 101, '-1': 94, '0': 58})
# accuracy: 0.34375
# predicted class counts: Counter({-1: 34, 1: 16, 0: 14})
# COP accuracy: (-1, 0.34375). Average accuracy:0.3950352822580645
# Data spread:  Counter({'1': 102, '0': 97, '-1': 54})
# accuracy: 0.265625
# predicted class counts: Counter({0: 48, 1: 9, -1: 7})
# ED accuracy: (0, 0.265625). Average accuracy:0.394
# Data spread:  Counter({'1': 105, '-1': 81, '0': 67})
# accuracy: 0.3125
# predicted class counts: Counter({1: 29, -1: 18, 0: 17})
# STZ accuracy: (1, 0.3125). Average accuracy:0.3933531746031746
# Data spread:  Counter({'1': 105, '0': 82, '-1': 66})
# accuracy: 0.296875
# predicted class counts: Counter({1: 24, -1: 23, 0: 17})
# COO accuracy: (0, 0.296875). Average accuracy:0.39259350393700787
# Data spread:  Counter({'1': 139, '0': 66, '-1': 48})
# accuracy: 0.484375
# predicted class counts: Counter({1: 49, -1: 8, 0: 7})
# CPRT accuracy: (1, 0.484375). Average accuracy:0.393310546875
# Data spread:  Counter({'1': 100, '-1': 86, '0': 67})
# {count} / 500 trained
# accuracy: 0.296875
# predicted class counts: Counter({-1: 40, 1: 16, 0: 8})
# GLW accuracy: (1, 0.296875). Average accuracy:0.39256298449612403
# Data spread:  Counter({'0': 115, '1': 73, '-1': 65})
# accuracy: 0.4838709677419355
# predicted class counts: Counter({0: 54, -1: 5, 1: 3})
# CTVA accuracy: (0, 0.4838709677419355). Average accuracy:0.3932653535980149
# Data spread:  Counter({'1': 106, '0': 105, '-1': 42})
# accuracy: 0.421875
# predicted class counts: Counter({1: 31, 0: 29, -1: 4})
# COST accuracy: (1, 0.421875). Average accuracy:0.3934837478453583
# Data spread:  Counter({'-1': 99, '1': 94, '0': 60})
# accuracy: 0.3125
# predicted class counts: Counter({-1: 50, 1: 12, 0: 2})
# COTY accuracy: (-1, 0.3125). Average accuracy:0.3928702346041056
# Data spread:  Counter({'1': 118, '0': 74, '-1': 61})
# accuracy: 0.359375
# predicted class counts: Counter({1: 45, 0: 15, -1: 4})
# CCI accuracy: (1, 0.359375). Average accuracy:0.3926183907349018
# Data spread:  Counter({'1': 103, '0': 77, '-1': 73})
# accuracy: 0.375
# predicted class counts: Counter({1: 26, -1: 19, 0: 19})
# CSX accuracy: (1, 0.375). Average accuracy:0.39248691020702936
# Data spread:  Counter({'1': 115, '0': 70, '-1': 68})
# accuracy: 0.328125
# predicted class counts: Counter({1: 37, 0: 19, -1: 8})
# CMI accuracy: (0, 0.328125). Average accuracy:0.39201015531660693
# Data spread:  Counter({'1': 107, '-1': 79, '0': 67})
# accuracy: 0.359375
# predicted class counts: Counter({-1: 31, 1: 22, 0: 11})
# CVS accuracy: (-1, 0.359375). Average accuracy:0.39177019093927895
# Data spread:  Counter({'1': 115, '0': 70, '-1': 68})
# accuracy: 0.359375
# predicted class counts: Counter({-1: 27, 1: 21, 0: 16})
# DHI accuracy: (-1, 0.359375). Average accuracy:0.391533729691547
# Data spread:  Counter({'1': 118, '0': 78, '-1': 57})
# accuracy: 0.421875
# predicted class counts: Counter({1: 36, 0: 20, -1: 8})
# DHR accuracy: (-1, 0.421875). Average accuracy:0.39175359396914444
# Data spread:  Counter({'1': 104, '-1': 80, '0': 69})
# {count} / 500 trained
# accuracy: 0.375
# predicted class counts: Counter({1: 34, -1: 18, 0: 12})
# DRI accuracy: (0, 0.375). Average accuracy:0.39163306451612906
# Data spread:  Counter({'1': 116, '-1': 79, '0': 58})
# accuracy: 0.328125
# predicted class counts: Counter({1: 28, -1: 25, 0: 11})
# DVA accuracy: (1, 0.328125). Average accuracy:0.39117943548387096
# Data spread:  Counter({'1': 109, '0': 73, '-1': 71})
# accuracy: 0.28125
# predicted class counts: Counter({1: 39, 0: 13, -1: 12})
# DE accuracy: (1, 0.28125). Average accuracy:0.39039979409746056
# Data spread:  Counter({'1': 107, '-1': 89, '0': 57})
# accuracy: 0.25
# predicted class counts: Counter({-1: 36, 1: 21, 0: 7})
# DAL accuracy: (0, 0.25). Average accuracy:0.38941106315311225
# Data spread:  Counter({'1': 104, '0': 88, '-1': 61})
# accuracy: 0.375
# predicted class counts: Counter({1: 31, 0: 28, -1: 5})
# XRAY accuracy: (1, 0.375). Average accuracy:0.3893102864877058
# Data spread:  Counter({'1': 110, '-1': 106, '0': 37})
# accuracy: 0.46875
# predicted class counts: Counter({-1: 34, 1: 30})
# DVN accuracy: (-1, 0.46875). Average accuracy:0.38986195116487454
# Data spread:  Counter({'1': 106, '-1': 92, '0': 55})
# accuracy: 0.390625
# predicted class counts: Counter({1: 29, -1: 28, 0: 7})
# FANG accuracy: (-1, 0.390625). Average accuracy:0.38986721357063403
# Data spread:  Counter({'1': 115, '-1': 79, '0': 59})
# accuracy: 0.34375
# predicted class counts: Counter({1: 50, -1: 11, 0: 3})
# DLR accuracy: (-1, 0.34375). Average accuracy:0.38955134224480775
# Data spread:  Counter({'1': 115, '0': 73, '-1': 65})
# accuracy: 0.359375
# predicted class counts: Counter({1: 41, 0: 16, -1: 7})
# DFS accuracy: (0, 0.359375). Average accuracy:0.3893460610050472
# Data spread:  Counter({'1': 105, '-1': 80, '0': 68})
# accuracy: 0.25
# predicted class counts: Counter({-1: 41, 1: 17, 0: 6})
# DISCA accuracy: (-1, 0.25). Average accuracy:0.3884045335658239
# Data spread:  Counter({'1': 113, '-1': 77, '0': 63})
# {count} / 500 trained
# accuracy: 0.375
# predicted class counts: Counter({1: 35, -1: 15, 0: 14})
# DISCK accuracy: (-1, 0.375). Average accuracy:0.38831457025330157
# Data spread:  Counter({'1': 116, '-1': 79, '0': 58})
# accuracy: 0.359375
# predicted class counts: Counter({1: 54, -1: 7, 0: 3})
# DISH accuracy: (1, 0.359375). Average accuracy:0.38812163978494624
# Data spread:  Counter({'1': 115, '0': 81, '-1': 57})
# accuracy: 0.578125
# predicted class counts: Counter({1: 34, 0: 22, -1: 8})
# DG accuracy: (-1, 0.578125). Average accuracy:0.3893799401837214
# Data spread:  Counter({'1': 107, '-1': 87, '0': 59})
# accuracy: 0.34375
# predicted class counts: Counter({-1: 33, 1: 26, 0: 5})
# DLTR accuracy: (1, 0.34375). Average accuracy:0.38907974320882854
# Data spread:  Counter({'1': 102, '0': 100, '-1': 51})
# accuracy: 0.34375
# predicted class counts: Counter({0: 49, 1: 13, -1: 2})
# D accuracy: (0, 0.34375). Average accuracy:0.38878347037739824
# Data spread:  Counter({'1': 114, '0': 84, '-1': 55})
# accuracy: 0.453125
# predicted class counts: Counter({1: 38, 0: 25, -1: 1})
# DOV accuracy: (-1, 0.453125). Average accuracy:0.3892012725178048
# Data spread:  Counter({'1': 89, '0': 84, '-1': 80})
# accuracy: 0.3387096774193548
# predicted class counts: Counter({0: 40, -1: 16, 1: 6})
# DOW accuracy: (0, 0.3387096774193548). Average accuracy:0.3888755202913632
# Data spread:  Counter({'0': 116, '1': 91, '-1': 46})
# accuracy: 0.4375
# predicted class counts: Counter({0: 58, 1: 5, -1: 1})
# DTE accuracy: (0, 0.4375). Average accuracy:0.38918721567411085
# Data spread:  Counter({'0': 114, '1': 90, '-1': 49})
# accuracy: 0.390625
# predicted class counts: Counter({0: 49, 1: 14, -1: 1})
# DUK accuracy: (1, 0.390625). Average accuracy:0.3891963735360592
# Data spread:  Counter({'1': 113, '0': 88, '-1': 52})
# accuracy: 0.328125
# predicted class counts: Counter({1: 30, 0: 29, -1: 5})
# DRE accuracy: (-1, 0.328125). Average accuracy:0.3888098458554512
# Data spread:  Counter({'-1': 103, '1': 94, '0': 56})
# {count} / 500 trained
# accuracy: 0.40625
# predicted class counts: Counter({-1: 38, 1: 17, 0: 9})
# DD accuracy: (-1, 0.40625). Average accuracy:0.388919532359505
# Data spread:  Counter({'1': 110, '-1': 100, '0': 43})
# accuracy: 0.328125
# predicted class counts: Counter({-1: 50, 1: 14})
# DXC accuracy: (-1, 0.328125). Average accuracy:0.3885395665322581
# Data spread:  Counter({'1': 116, '-1': 85, '0': 52})
# accuracy: 0.359375
# predicted class counts: Counter({1: 44, -1: 16, 0: 4})
# ETFC accuracy: (1, 0.359375). Average accuracy:0.3883584201562813
# Data spread:  Counter({'1': 113, '-1': 102, '0': 38})
# accuracy: 0.453125
# predicted class counts: Counter({1: 34, -1: 30})
# EMN accuracy: (1, 0.453125). Average accuracy:0.3887582138590203
# Data spread:  Counter({'1': 107, '0': 77, '-1': 69})
# accuracy: 0.421875
# predicted class counts: Counter({1: 33, 0: 17, -1: 14})
# ETN accuracy: (1, 0.421875). Average accuracy:0.3889613843261429
# Data spread:  Counter({'1': 109, '-1': 73, '0': 71})
# accuracy: 0.3125
# predicted class counts: Counter({1: 36, -1: 17, 0: 11})
# EBAY accuracy: (1, 0.3125). Average accuracy:0.3884951563729347
# Data spread:  Counter({'1': 104, '0': 94, '-1': 55})
# accuracy: 0.359375
# predicted class counts: Counter({1: 29, 0: 25, -1: 10})
# ECL accuracy: (-1, 0.359375). Average accuracy:0.3883186705767351
# Data spread:  Counter({'1': 126, '-1': 64, '0': 63})
# accuracy: 0.375
# predicted class counts: Counter({1: 42, -1: 19, 0: 3})
# EIX accuracy: (1, 0.375). Average accuracy:0.38823843762145355
# Data spread:  Counter({'1': 109, '0': 81, '-1': 63})
# accuracy: 0.34375
# predicted class counts: Counter({1: 36, 0: 15, -1: 13})
# EW accuracy: (1, 0.34375). Average accuracy:0.38797203979138495
# Data spread:  Counter({'1': 114, '-1': 81, '0': 58})
# accuracy: 0.5
# predicted class counts: Counter({1: 34, -1: 22, 0: 8})
# EA accuracy: (1, 0.5). Average accuracy:0.3886388728878648
# Data spread:  Counter({'1': 111, '0': 82, '-1': 60})
# {count} / 500 trained
# accuracy: 0.375
# predicted class counts: Counter({1: 42, 0: 17, -1: 5})
# EMR accuracy: (1, 0.375). Average accuracy:0.3885581694979958
# Data spread:  Counter({'1': 122, '0': 98, '-1': 33})
# accuracy: 0.4375
# predicted class counts: Counter({0: 37, 1: 25, -1: 2})
# ETR accuracy: (1, 0.4375). Average accuracy:0.38884606261859583
# Data spread:  Counter({'-1': 105, '1': 102, '0': 46})
# accuracy: 0.40625
# predicted class counts: Counter({-1: 36, 1: 21, 0: 7})
# EOG accuracy: (1, 0.40625). Average accuracy:0.388947840030183
# Data spread:  Counter({'1': 124, '0': 81, '-1': 48})
# accuracy: 0.5
# predicted class counts: Counter({1: 50, 0: 12, -1: 2})
# EFX accuracy: (1, 0.5). Average accuracy:0.38959349212303074
# Data spread:  Counter({'1': 126, '0': 69, '-1': 58})
# accuracy: 0.390625
# predicted class counts: Counter({1: 34, 0: 17, -1: 13})
# EQIX accuracy: (0, 0.390625). Average accuracy:0.389599454596308
# Data spread:  Counter({'1': 100, '0': 100, '-1': 53})
# accuracy: 0.34375
# predicted class counts: Counter({0: 47, 1: 14, -1: 3})
# EQR accuracy: (0, 0.34375). Average accuracy:0.3893359519836856
# Data spread:  Counter({'1': 104, '0': 96, '-1': 53})
# accuracy: 0.40625
# predicted class counts: Counter({0: 34, 1: 18, -1: 12})
# ESS accuracy: (0, 0.40625). Average accuracy:0.38943260368663596
# Data spread:  Counter({'1': 128, '0': 69, '-1': 56})
# accuracy: 0.484375
# predicted class counts: Counter({1: 42, 0: 16, -1: 6})
# EL accuracy: (1, 0.484375). Average accuracy:0.3899720491202346
# Data spread:  Counter({'0': 119, '1': 90, '-1': 44})
# accuracy: 0.5625
# predicted class counts: Counter({0: 55, 1: 6, -1: 3})
# EVRG accuracy: (0, 0.5625). Average accuracy:0.39094678330599597
# Data spread:  Counter({'0': 117, '1': 100, '-1': 36})
# accuracy: 0.4375
# predicted class counts: Counter({0: 57, 1: 5, -1: 2})
# ES accuracy: (1, 0.4375). Average accuracy:0.3912083182312432
# Data spread:  Counter({'1': 109, '0': 85, '-1': 59})
# {count} / 500 trained
# accuracy: 0.34375
# predicted class counts: Counter({0: 30, 1: 20, -1: 14})
# RE accuracy: (-1, 0.34375). Average accuracy:0.3909431879617949
# Data spread:  Counter({'0': 102, '1': 89, '-1': 62})
# accuracy: 0.40625
# predicted class counts: Counter({0: 49, -1: 9, 1: 6})
# EXC accuracy: (0, 0.40625). Average accuracy:0.39102822580645163
# Data spread:  Counter({'1': 117, '-1': 71, '0': 65})
# accuracy: 0.328125
# predicted class counts: Counter({1: 41, -1: 14, 0: 9})
# EXPE accuracy: (1, 0.328125). Average accuracy:0.39068069417216184
# Data spread:  Counter({'1': 98, '-1': 78, '0': 77})
# accuracy: 0.328125
# predicted class counts: Counter({0: 28, -1: 25, 1: 11})
# EXPD accuracy: (-1, 0.328125). Average accuracy:0.3903369815668203
# Data spread:  Counter({'1': 101, '0': 87, '-1': 65})
# accuracy: 0.34375
# predicted class counts: Counter({0: 44, 1: 13, -1: 7})
# EXR accuracy: (0, 0.34375). Average accuracy:0.3900824078970562
# Data spread:  Counter({'0': 91, '1': 89, '-1': 73})
# accuracy: 0.3125
# predicted class counts: Counter({1: 24, 0: 22, -1: 18})
# XOM accuracy: (1, 0.3125). Average accuracy:0.3896607643758766
# Data spread:  Counter({'-1': 109, '1': 93, '0': 51})
# accuracy: 0.390625
# predicted class counts: Counter({-1: 46, 1: 14, 0: 4})
# FFIV accuracy: (-1, 0.390625). Average accuracy:0.3896659764603313
# Data spread:  Counter({'1': 117, '-1': 82, '0': 54})
# accuracy: 0.4375
# predicted class counts: Counter({-1: 31, 1: 27, 0: 6})
# FB accuracy: (0, 0.4375). Average accuracy:0.3899231486298994
# Data spread:  Counter({'1': 109, '-1': 84, '0': 60})
# accuracy: 0.5
# predicted class counts: Counter({1: 37, -1: 24, 0: 3})
# FAST accuracy: (1, 0.5). Average accuracy:0.39051179489391064
# Data spread:  Counter({'0': 101, '1': 85, '-1': 67})
# accuracy: 0.359375
# predicted class counts: Counter({0: 40, 1: 16, -1: 8})
# FRT accuracy: (0, 0.359375). Average accuracy:0.39034617364447494
# Data spread:  Counter({'1': 109, '-1': 102, '0': 42})
# {count} / 500 trained
# accuracy: 0.390625
# predicted class counts: Counter({-1: 39, 1: 22, 0: 3})
# FDX accuracy: (-1, 0.390625). Average accuracy:0.3903476489161973
# Data spread:  Counter({'1': 112, '0': 88, '-1': 53})
# accuracy: 0.390625
# predicted class counts: Counter({1: 31, 0: 21, -1: 12})
# FIS accuracy: (0, 0.390625). Average accuracy:0.3903491086587436
# Data spread:  Counter({'1': 116, '-1': 79, '0': 58})
# accuracy: 0.46875
# predicted class counts: Counter({1: 33, -1: 25, 0: 6})
# FITB accuracy: (1, 0.46875). Average accuracy:0.39075958452964027
# Data spread:  Counter({'0': 110, '1': 102, '-1': 41})
# accuracy: 0.453125
# predicted class counts: Counter({0: 47, 1: 17})
# FE accuracy: (0, 0.453125). Average accuracy:0.39108440440188175
# Data spread:  Counter({'1': 115, '-1': 73, '0': 65})
# accuracy: 0.375
# predicted class counts: Counter({1: 32, -1: 21, 0: 11})
# FRC accuracy: (-1, 0.375). Average accuracy:0.3910010655189704
# Data spread:  Counter({'1': 110, '0': 94, '-1': 49})
# accuracy: 0.46875
# predicted class counts: Counter({0: 35, 1: 26, -1: 3})
# FISV accuracy: (0, 0.46875). Average accuracy:0.3914018332224809
# Data spread:  Counter({'1': 122, '0': 73, '-1': 58})
# accuracy: 0.515625
# predicted class counts: Counter({1: 47, -1: 9, 0: 8})
# FLT accuracy: (1, 0.515625). Average accuracy:0.39203887510339125
# Data spread:  Counter({'1': 105, '0': 80, '-1': 68})
# accuracy: 0.375
# predicted class counts: Counter({1: 33, 0: 22, -1: 9})
# FLIR accuracy: (1, 0.375). Average accuracy:0.39195194206714945
# Data spread:  Counter({'1': 121, '-1': 83, '0': 49})
# accuracy: 0.28125
# predicted class counts: Counter({1: 32, -1: 25, 0: 7})
# FLS accuracy: (1, 0.28125). Average accuracy:0.3913900032749304
# Data spread:  Counter({'1': 114, '-1': 72, '0': 67})
# accuracy: 0.4375
# predicted class counts: Counter({1: 43, 0: 13, -1: 8})
# FMC accuracy: (1, 0.4375). Average accuracy:0.39162288204626916
# Data spread:  Counter({'1': 107, '-1': 89, '0': 57})
# {count} / 500 trained
# accuracy: 0.265625
# predicted class counts: Counter({1: 35, -1: 28, 0: 1})
# F accuracy: (-1, 0.265625). Average accuracy:0.39098972686010697
# Data spread:  Counter({'1': 121, '-1': 73, '0': 59})
# accuracy: 0.40625
# predicted class counts: Counter({1: 40, -1: 18, 0: 6})
# FTNT accuracy: (1, 0.40625). Average accuracy:0.39106602822580644
# Data spread:  Counter({'1': 103, '-1': 80, '0': 70})
# accuracy: 0.421875
# predicted class counts: Counter({-1: 26, 1: 24, 0: 14})
# FTV accuracy: (-1, 0.421875). Average accuracy:0.3912193066923447
# Data spread:  Counter({'1': 130, '0': 65, '-1': 58})
# accuracy: 0.390625
# predicted class counts: Counter({1: 51, -1: 12, 0: 1})
# FBHS accuracy: (1, 0.390625). Average accuracy:0.3912163645800064
# Data spread:  Counter({'1': 90, '0': 85, '-1': 78})
# accuracy: 0.27419354838709675
# predicted class counts: Counter({0: 38, -1: 19, 1: 5})
# FOXA accuracy: (0, 0.27419354838709675). Average accuracy:0.3906398975051645
# Data spread:  Counter({'1': 89, '0': 87, '-1': 77})
# accuracy: 0.3548387096774194
# predicted class counts: Counter({0: 34, -1: 21, 1: 7})
# FOX accuracy: (0, 0.3548387096774194). Average accuracy:0.390464401486401
# Data spread:  Counter({'-1': 92, '1': 91, '0': 70})
# accuracy: 0.234375
# predicted class counts: Counter({-1: 46, 1: 10, 0: 8})
# BEN accuracy: (-1, 0.234375). Average accuracy:0.3897029897718332
# Data spread:  Counter({'1': 125, '-1': 93, '0': 35})
# accuracy: 0.375
# predicted class counts: Counter({1: 45, -1: 18, 0: 1})
# FCX accuracy: (-1, 0.375). Average accuracy:0.38963161603507673
# Data spread:  Counter({'-1': 115, '1': 85, '0': 53})
# accuracy: 0.40625
# predicted class counts: Counter({-1: 54, 1: 7, 0: 3})
# GPS accuracy: (-1, 0.40625). Average accuracy:0.38971189808321643
# Data spread:  Counter({'1': 119, '0': 84, '-1': 50})
# accuracy: 0.375
# predicted class counts: Counter({1: 36, 0: 26, -1: 2})
# GRMN accuracy: (0, 0.375). Average accuracy:0.38964116780397023
# Data spread:  Counter({'1': 115, '0': 87, '-1': 51})
# {count} / 500 trained
# accuracy: 0.453125
# predicted class counts: Counter({1: 44, 0: 15, -1: 5})
# IT accuracy: (-1, 0.453125). Average accuracy:0.3899449181972527
# Data spread:  Counter({'1': 104, '-1': 80, '0': 69})
# accuracy: 0.40625
# predicted class counts: Counter({-1: 28, 1: 27, 0: 9})
# GD accuracy: (-1, 0.40625). Average accuracy:0.39002256144393244
# Data spread:  Counter({'1': 117, '-1': 86, '0': 50})
# accuracy: 0.390625
# predicted class counts: Counter({1: 34, -1: 28, 0: 2})
# GE accuracy: (-1, 0.390625). Average accuracy:0.3900254166029659
# Data spread:  Counter({'1': 108, '0': 88, '-1': 57})
# accuracy: 0.359375
# predicted class counts: Counter({0: 36, 1: 22, -1: 6})
# GIS accuracy: (-1, 0.359375). Average accuracy:0.38988083916615945
# Data spread:  Counter({'1': 109, '-1': 93, '0': 51})
# accuracy: 0.296875
# predicted class counts: Counter({-1: 29, 1: 23, 0: 12})
# GM accuracy: (-1, 0.296875). Average accuracy:0.389444192033924
# Data spread:  Counter({'1': 100, '0': 77, '-1': 76})
# accuracy: 0.484375
# predicted class counts: Counter({1: 28, 0: 22, -1: 14})
# GPC accuracy: (-1, 0.484375). Average accuracy:0.3898877939403075
# Data spread:  Counter({'-1': 96, '1': 91, '0': 66})
# accuracy: 0.328125
# predicted class counts: Counter({-1: 45, 1: 14, 0: 5})
# GILD accuracy: (0, 0.328125). Average accuracy:0.3896005251312828
# Data spread:  Counter({'1': 110, '0': 104, '-1': 39})
# accuracy: 0.296875
# predicted class counts: Counter({0: 54, 1: 9, -1: 1})
# GL accuracy: (1, 0.296875). Average accuracy:0.38917124029271205
# Data spread:  Counter({'1': 139, '0': 69, '-1': 45})
# accuracy: 0.4375
# predicted class counts: Counter({1: 41, 0: 15, -1: 8})
# GPN accuracy: (0, 0.4375). Average accuracy:0.3893939534710867
# Data spread:  Counter({'1': 123, '-1': 75, '0': 55})
# accuracy: 0.4375
# predicted class counts: Counter({1: 43, -1: 11, 0: 10})
# GS accuracy: (1, 0.4375). Average accuracy:0.3896146234092927
# Data spread:  Counter({'1': 107, '-1': 84, '0': 62})
# {count} / 500 trained
# accuracy: 0.375
# predicted class counts: Counter({-1: 27, 1: 24, 0: 13})
# GWW accuracy: (0, 0.375). Average accuracy:0.3895478899690676
# Data spread:  Counter({'0': 90, '-1': 84, '1': 79})
# accuracy: 0.3125
# predicted class counts: Counter({0: 30, -1: 27, 1: 7})
# HRB accuracy: (0, 0.3125). Average accuracy:0.38919767228739005
# Data spread:  Counter({'1': 114, '-1': 102, '0': 37})
# accuracy: 0.328125
# predicted class counts: Counter({1: 49, -1: 13, 0: 2})
# HAL accuracy: (1, 0.328125). Average accuracy:0.3889213253539629
# Data spread:  Counter({'-1': 109, '1': 98, '0': 46})
# accuracy: 0.453125
# predicted class counts: Counter({-1: 42, 1: 20, 0: 2})
# HBI accuracy: (1, 0.453125). Average accuracy:0.38921053109561177
# Data spread:  Counter({'-1': 107, '1': 97, '0': 49})
# accuracy: 0.421875
# predicted class counts: Counter({-1: 50, 1: 14})
# HOG accuracy: (-1, 0.421875). Average accuracy:0.3893570085346449
# Data spread:  Counter({'1': 113, '0': 103, '-1': 37})
# accuracy: 0.390625
# predicted class counts: Counter({0: 34, 1: 30})
# HIG accuracy: (1, 0.390625). Average accuracy:0.3893626692108295
# Data spread:  Counter({'1': 120, '-1': 70, '0': 63})
# accuracy: 0.375
# predicted class counts: Counter({1: 37, -1: 20, 0: 7})
# HAS accuracy: (0, 0.375). Average accuracy:0.38929883512544805
# Data spread:  Counter({'1': 127, '-1': 70, '0': 56})
# accuracy: 0.40625
# predicted class counts: Counter({1: 46, -1: 13, 0: 5})
# HCA accuracy: (1, 0.40625). Average accuracy:0.3893738402797602
# Data spread:  Counter({'1': 119, '0': 70, '-1': 64})
# accuracy: 0.25
# predicted class counts: Counter({1: 27, 0: 23, -1: 14})
# PEAK accuracy: (-1, 0.25). Average accuracy:0.38875985860451895
# Data spread:  Counter({'1': 107, '-1': 104, '0': 42})
# accuracy: 0.390625
# predicted class counts: Counter({1: 47, -1: 17})
# HP accuracy: (1, 0.390625). Average accuracy:0.388768039049236
# Data spread:  Counter({'1': 90, '-1': 90, '0': 73})
# {count} / 500 trained
# accuracy: 0.46875
# predicted class counts: Counter({-1: 35, 0: 23, 1: 6})
# HSIC accuracy: (0, 0.46875). Average accuracy:0.38911730525426114
# Data spread:  Counter({'1': 120, '0': 82, '-1': 51})
# accuracy: 0.3125
# predicted class counts: Counter({1: 38, 0: 22, -1: 4})
# HSY accuracy: (1, 0.3125). Average accuracy:0.38878418653576435
# Data spread:  Counter({'1': 135, '-1': 77, '0': 41})
# accuracy: 0.46875
# predicted class counts: Counter({1: 49, -1: 13, 0: 2})
# HES accuracy: (-1, 0.46875). Average accuracy:0.3891303588884234
# Data spread:  Counter({'1': 120, '-1': 86, '0': 47})
# accuracy: 0.4375
# predicted class counts: Counter({1: 40, -1: 21, 0: 3})
# HPE accuracy: (-1, 0.4375). Average accuracy:0.3893388487208009
# Data spread:  Counter({'1': 126, '0': 70, '-1': 57})
# accuracy: 0.515625
# predicted class counts: Counter({1: 43, 0: 17, -1: 4})
# HLT accuracy: (0, 0.515625). Average accuracy:0.38988084937006784
# Data spread:  Counter({'1': 110, '-1': 102, '0': 41})
# accuracy: 0.40625
# predicted class counts: Counter({-1: 33, 1: 29, 0: 2})
# HFC accuracy: (-1, 0.40625). Average accuracy:0.3899508030052385
# Data spread:  Counter({'1': 108, '0': 73, '-1': 72})
# accuracy: 0.328125
# predicted class counts: Counter({1: 36, -1: 15, 0: 13})
# HOLX accuracy: (1, 0.328125). Average accuracy:0.38968771448181194
# Data spread:  Counter({'1': 107, '0': 74, '-1': 72})
# accuracy: 0.375
# predicted class counts: Counter({1: 42, -1: 16, 0: 6})
# HD accuracy: (-1, 0.375). Average accuracy:0.3896254784034992
# Data spread:  Counter({'1': 112, '0': 84, '-1': 57})
# accuracy: 0.3125
# predicted class counts: Counter({1: 33, 0: 22, -1: 9})
# HON accuracy: (1, 0.3125). Average accuracy:0.38930005444399074
# Data spread:  Counter({'1': 92, '0': 91, '-1': 70})
# accuracy: 0.34375
# predicted class counts: Counter({0: 42, -1: 14, 1: 8})
# HRL accuracy: (-1, 0.34375). Average accuracy:0.38910866766061264
# Data spread:  Counter({'1': 92, '0': 84, '-1': 77})
# {count} / 500 trained
# accuracy: 0.203125
# predicted class counts: Counter({-1: 28, 0: 24, 1: 12})
# HST accuracy: (-1, 0.203125). Average accuracy:0.38833049331893643
# Data spread:  Counter({'1': 120, '-1': 71, '0': 62})
# accuracy: 0.421875
# predicted class counts: Counter({1: 41, -1: 13, 0: 10})
# HPQ accuracy: (1, 0.421875). Average accuracy:0.3884702620967742
# Data spread:  Counter({'1': 123, '-1': 88, '0': 42})
# accuracy: 0.375
# predicted class counts: Counter({1: 34, -1: 29, 0: 1})
# HUM accuracy: (-1, 0.375). Average accuracy:0.38841436889305314
# Data spread:  Counter({'1': 106, '0': 78, '-1': 69})
# accuracy: 0.3125
# predicted class counts: Counter({1: 37, -1: 17, 0: 10})
# HBAN accuracy: (1, 0.3125). Average accuracy:0.3881006731538256
# Data spread:  Counter({'1': 126, '-1': 65, '0': 62})
# accuracy: 0.390625
# predicted class counts: Counter({1: 34, -1: 18, 0: 12})
# HII accuracy: (1, 0.390625). Average accuracy:0.38811106133014733
# Data spread:  Counter({'1': 110, '0': 91, '-1': 52})
# accuracy: 0.34375
# predicted class counts: Counter({-1: 24, 1: 22, 0: 18})
# IEX accuracy: (1, 0.34375). Average accuracy:0.38792925370174514
# Data spread:  Counter({'1': 127, '0': 67, '-1': 59})
# accuracy: 0.453125
# predicted class counts: Counter({1: 45, 0: 12, -1: 7})
# IDXX accuracy: (-1, 0.453125). Average accuracy:0.3881953587886768
# Data spread:  Counter({'1': 113, '0': 106, '-1': 34})
# accuracy: 0.40625
# predicted class counts: Counter({0: 41, 1: 21, -1: 2})
# INFO accuracy: (1, 0.40625). Average accuracy:0.3882687516391293
# Data spread:  Counter({'1': 116, '-1': 69, '0': 68})
# accuracy: 0.390625
# predicted class counts: Counter({1: 37, 0: 14, -1: 13})
# ITW accuracy: (0, 0.390625). Average accuracy:0.38827829110617734
# Data spread:  Counter({'1': 116, '-1': 83, '0': 54})
# accuracy: 0.375
# predicted class counts: Counter({1: 29, -1: 26, 0: 9})
# ILMN accuracy: (-1, 0.375). Average accuracy:0.3882247496097815
# Data spread:  Counter({'1': 107, '0': 87, '-1': 59})
# {count} / 500 trained
# accuracy: 0.328125
# predicted class counts: Counter({1: 32, 0: 28, -1: 4})
# IR accuracy: (0, 0.328125). Average accuracy:0.38798338515351727
# Data spread:  Counter({'1': 125, '-1': 65, '0': 63})
# ...
# accuracy: 0.4444444444444444
# predicted class counts: Counter({0: 35, 1: 21, -1: 7})
# SO accuracy: (1, 0.4444444444444444). Average accuracy:0.38739083956955195
# Data spread:  Counter({'1': 97, '-1': 87, '0': 69})
# accuracy: 0.328125
# predicted class counts: Counter({-1: 28, 1: 23, 0: 13})
# LUV accuracy: (-1, 0.328125). Average accuracy:0.387250399191425
# Data spread:  Counter({'1': 110, '-1': 81, '0': 62})
# accuracy: 0.34375
# predicted class counts: Counter({-1: 38, 1: 22, 0: 4})
# SWK accuracy: (0, 0.34375). Average accuracy:0.38714756136827744
# Data spread:  Counter({'1': 119, '0': 89, '-1': 45})
# accuracy: 0.375
# predicted class counts: Counter({0: 33, 1: 24, -1: 7})
# SBUX accuracy: (0, 0.375). Average accuracy:0.38711891145939
# Data spread:  Counter({'1': 111, '-1': 90, '0': 52})
# accuracy: 0.375
# predicted class counts: Counter({1: 31, -1: 27, 0: 6})
# STT accuracy: (-1, 0.375). Average accuracy:0.3870903963736032
# Data spread:  Counter({'1': 121, '0': 79, '-1': 53})
# accuracy: 0.453125
# predicted class counts: Counter({1: 36, 0: 15, -1: 13})
# STE accuracy: (1, 0.453125). Average accuracy:0.3872454071802379
# Data spread:  Counter({'1': 111, '0': 83, '-1': 59})
# accuracy: 0.390625
# predicted class counts: Counter({0: 26, 1: 23, -1: 15})
# SYK accuracy: (1, 0.390625). Average accuracy:0.38725332191752077
# Data spread:  Counter({'1': 117, '-1': 83, '0': 53})
# accuracy: 0.390625
# predicted class counts: Counter({1: 36, -1: 23, 0: 5})
# SIVB accuracy: (1, 0.390625). Average accuracy:0.3872611996700499
# Data spread:  Counter({'1': 114, '0': 83, '-1': 56})
# {count} / 500 trained
# accuracy: 0.296875
# predicted class counts: Counter({1: 43, 0: 20, -1: 1})
# SYF accuracy: (1, 0.296875). Average accuracy:0.3870505092279286
# Data spread:  Counter({'1': 126, '0': 80, '-1': 47})
# accuracy: 0.484375
# predicted class counts: Counter({1: 42, 0: 16, -1: 6})
# SNPS accuracy: (-1, 0.484375). Average accuracy:0.3872768452529799
# Data spread:  Counter({'1': 119, '0': 91, '-1': 43})
# accuracy: 0.359375
# predicted class counts: Counter({1: 34, 0: 24, -1: 6})
# SYY accuracy: (0, 0.359375). Average accuracy:0.3872121077929962
# Data spread:  Counter({'1': 105, '0': 76, '-1': 72})
# accuracy: 0.40625
# predicted class counts: Counter({1: 31, -1: 20, 0: 13})
# TMUS accuracy: (1, 0.40625). Average accuracy:0.3872561769879198
# Data spread:  Counter({'1': 104, '0': 87, '-1': 62})
# accuracy: 0.390625
# predicted class counts: Counter({0: 28, 1: 21, -1: 15})
# TROW accuracy: (-1, 0.390625). Average accuracy:0.38726395717963363
# Data spread:  Counter({'1': 111, '-1': 81, '0': 61})
# accuracy: 0.40625
# predicted class counts: Counter({1: 34, -1: 26, 0: 4})
# TTWO accuracy: (-1, 0.40625). Average accuracy:0.38730770382207685
# Data spread:  Counter({'1': 102, '-1': 100, '0': 51})
# accuracy: 0.390625
# predicted class counts: Counter({-1: 39, 1: 22, 0: 3})
# TPR accuracy: (1, 0.390625). Average accuracy:0.387315329790302
# Data spread:  Counter({'1': 119, '0': 76, '-1': 58})
# accuracy: 0.328125
# predicted class counts: Counter({1: 33, 0: 19, -1: 12})
# TGT accuracy: (1, 0.328125). Average accuracy:0.3871795721531683
# Data spread:  Counter({'1': 111, '-1': 79, '0': 63})
# accuracy: 0.40625
# predicted class counts: Counter({1: 34, -1: 23, 0: 7})
# TEL accuracy: (0, 0.40625). Average accuracy:0.38722321157615874
# Data spread:  Counter({'1': 106, '-1': 101, '0': 46})
# accuracy: 0.375
# predicted class counts: Counter({1: 37, -1: 26, 0: 1})
# FTI accuracy: (1, 0.375). Average accuracy:0.3871953047004141
# Data spread:  Counter({'1': 125, '0': 70, '-1': 58})
# {count} / 500 trained
# accuracy: 0.421875
# predicted class counts: Counter({1: 36, 0: 22, -1: 6})
# TFX accuracy: (1, 0.421875). Average accuracy:0.38727430172843136
# Data spread:  Counter({'1': 121, '0': 66, '-1': 66})
# accuracy: 0.34375
# predicted class counts: Counter({1: 39, -1: 16, 0: 9})
# TXN accuracy: (1, 0.34375). Average accuracy:0.3871753828608667
# Data spread:  Counter({'-1': 100, '1': 94, '0': 59})
# accuracy: 0.46875
# predicted class counts: Counter({-1: 51, 1: 13})
# TXT accuracy: (-1, 0.46875). Average accuracy:0.38736035931696455
# Data spread:  Counter({'1': 132, '0': 62, '-1': 59})
# accuracy: 0.5
# predicted class counts: Counter({1: 53, -1: 7, 0: 4})
# TMO accuracy: (1, 0.5). Average accuracy:0.3876152001329895
# Data spread:  Counter({'1': 104, '0': 80, '-1': 69})
# accuracy: 0.453125
# predicted class counts: Counter({1: 33, 0: 24, -1: 7})
# TIF accuracy: (0, 0.453125). Average accuracy:0.38776307778505953
# Data spread:  Counter({'1': 108, '0': 86, '-1': 59})
# accuracy: 0.34375
# predicted class counts: Counter({0: 32, 1: 26, -1: 6})
# TJX accuracy: (0, 0.34375). Average accuracy:0.38766394923148956
# Data spread:  Counter({'1': 103, '-1': 84, '0': 66})
# accuracy: 0.296875
# predicted class counts: Counter({-1: 27, 1: 26, 0: 11})
# TSCO accuracy: (1, 0.296875). Average accuracy:0.38745992912085697
# Data spread:  Counter({'1': 124, '0': 66, '-1': 63})
# accuracy: 0.40625
# predicted class counts: Counter({1: 38, -1: 20, 0: 6})
# TDG accuracy: (1, 0.40625). Average accuracy:0.3875020593246219
# Data spread:  Counter({'0': 113, '1': 95, '-1': 45})
# accuracy: 0.40625
# predicted class counts: Counter({0: 55, 1: 6, -1: 3})
# TRV accuracy: (0, 0.40625). Average accuracy:0.3875440010263565
# Data spread:  Counter({'1': 97, '0': 95, '-1': 61})
# accuracy: 0.1875
# predicted class counts: Counter({1: 32, 0: 27, -1: 5})
# TFC accuracy: (0, 0.1875). Average accuracy:0.3870974742383513
# Data spread:  Counter({'1': 108, '-1': 91, '0': 54})
# {count} / 500 trained
# accuracy: 0.375
# predicted class counts: Counter({-1: 31, 1: 27, 0: 6})
# TWTR accuracy: (1, 0.375). Average accuracy:0.3870705310885999
# Data spread:  Counter({'1': 133, '-1': 65, '0': 55})
# accuracy: 0.359375
# predicted class counts: Counter({1: 41, -1: 17, 0: 6})
# TSN accuracy: (1, 0.359375). Average accuracy:0.38700898546395857
# Data spread:  Counter({'0': 114, '1': 89, '-1': 50})
# accuracy: 0.453125
# predicted class counts: Counter({0: 43, 1: 17, -1: 4})
# UDR accuracy: (0, 0.453125). Average accuracy:0.3871555841658123
# Data spread:  Counter({'1': 111, '-1': 74, '0': 68})
# accuracy: 0.359375
# predicted class counts: Counter({1: 37, 0: 16, -1: 11})
# ULTA accuracy: (-1, 0.359375). Average accuracy:0.38709412269641896
# Data spread:  Counter({'1': 109, '0': 86, '-1': 58})
# accuracy: 0.421875
# predicted class counts: Counter({0: 36, 1: 19, -1: 9})
# USB accuracy: (-1, 0.421875). Average accuracy:0.38717090167501406
# Data spread:  Counter({'1': 135, '-1': 94, '0': 24})
# accuracy: 0.46875
# predicted class counts: Counter({1: 47, -1: 17})
# UAA accuracy: (1, 0.46875). Average accuracy:0.3873505913189017
# Data spread:  Counter({'1': 133, '-1': 91, '0': 29})
# accuracy: 0.390625
# predicted class counts: Counter({1: 46, -1: 18})
# UA accuracy: (1, 0.390625). Average accuracy:0.3873577878214975
# Data spread:  Counter({'1': 106, '0': 79, '-1': 68})
# accuracy: 0.25
# predicted class counts: Counter({1: 34, -1: 17, 0: 13})
# UNP accuracy: (1, 0.25). Average accuracy:0.3870565646025907
# Data spread:  Counter({'1': 97, '-1': 89, '0': 67})
# accuracy: 0.375
# predicted class counts: Counter({-1: 34, 1: 15, 0: 15})
# UAL accuracy: (-1, 0.375). Average accuracy:0.387030182623154
# Data spread:  Counter({'1': 115, '-1': 80, '0': 58})
# accuracy: 0.484375
# predicted class counts: Counter({1: 47, -1: 10, 0: 7})
# UNH accuracy: (1, 0.484375). Average accuracy:0.3872427258925357
# Data spread:  Counter({'1': 99, '0': 77, '-1': 77})
# {count} / 500 trained
# accuracy: 0.34375
# predicted class counts: Counter({-1: 27, 0: 20, 1: 17})
# UPS accuracy: (1, 0.34375). Average accuracy:0.38714797049843436
# Data spread:  Counter({'1': 125, '-1': 83, '0': 45})
# accuracy: 0.4375
# predicted class counts: Counter({1: 50, -1: 12, 0: 2})
# URI accuracy: (1, 0.4375). Average accuracy:0.38725743143213337
# Data spread:  Counter({'1': 120, '0': 74, '-1': 59})
# accuracy: 0.28125
# predicted class counts: Counter({1: 42, 0: 16, -1: 6})
# UTX accuracy: (1, 0.28125). Average accuracy:0.38702748038781204
# Data spread:  Counter({'1': 97, '0': 83, '-1': 73})
# accuracy: 0.34375
# predicted class counts: Counter({0: 28, 1: 18, -1: 18})
# UHS accuracy: (-1, 0.34375). Average accuracy:0.38693380618783846
# Data spread:  Counter({'1': 101, '-1': 98, '0': 54})
# accuracy: 0.328125
# predicted class counts: Counter({-1: 43, 1: 17, 0: 4})
# UNM accuracy: (-1, 0.328125). Average accuracy:0.38680678932782153
# Data spread:  Counter({'1': 120, '0': 71, '-1': 62})
# accuracy: 0.421875
# predicted class counts: Counter({1: 35, 0: 20, -1: 9})
# VFC accuracy: (0, 0.421875). Average accuracy:0.3868823673680633
# Data spread:  Counter({'1': 117, '-1': 81, '0': 55})
# accuracy: 0.375
# predicted class counts: Counter({1: 35, -1: 22, 0: 7})
# VLO accuracy: (0, 0.375). Average accuracy:0.3868568138898524
# Data spread:  Counter({'1': 122, '-1': 72, '0': 59})
# accuracy: 0.3125
# predicted class counts: Counter({1: 45, -1: 10, 0: 9})
# VAR accuracy: (1, 0.3125). Average accuracy:0.38669724991154797
# Data spread:  Counter({'1': 103, '-1': 86, '0': 64})
# accuracy: 0.234375
# predicted class counts: Counter({-1: 36, 1: 15, 0: 13})
# VTR accuracy: (1, 0.234375). Average accuracy:0.38637107807019566
# Data spread:  Counter({'1': 104, '0': 92, '-1': 57})
# accuracy: 0.328125
# predicted class counts: Counter({0: 35, 1: 22, -1: 7})
# VRSN accuracy: (0, 0.328125). Average accuracy:0.3862466206384217
# Data spread:  Counter({'1': 119, '0': 95, '-1': 39})
# {count} / 500 trained
# accuracy: 0.390625
# predicted class counts: Counter({1: 39, 0: 20, -1: 5})
# VRSK accuracy: (1, 0.390625). Average accuracy:0.38625595620209247
# Data spread:  Counter({'0': 105, '1': 89, '-1': 59})
# accuracy: 0.359375
# predicted class counts: Counter({0: 49, 1: 11, -1: 4})
# VZ accuracy: (0, 0.359375). Average accuracy:0.3861987626782582
# Data spread:  Counter({'1': 107, '-1': 79, '0': 67})
# accuracy: 0.453125
# predicted class counts: Counter({-1: 31, 1: 18, 0: 15})
# VRTX accuracy: (1, 0.453125). Average accuracy:0.38634085660038503
# Data spread:  Counter({'-1': 109, '1': 96, '0': 48})
# accuracy: 0.4375
# predicted class counts: Counter({-1: 44, 1: 14, 0: 6})
# VIAC accuracy: (1, 0.4375). Average accuracy:0.3864492446160622
# Data spread:  Counter({'1': 111, '0': 101, '-1': 41})
# accuracy: 0.28125
# predicted class counts: Counter({0: 36, 1: 27, -1: 1})
# V accuracy: (1, 0.28125). Average accuracy:0.38622683606507685
# Data spread:  Counter({'0': 87, '1': 86, '-1': 80})
# accuracy: 0.328125
# predicted class counts: Counter({0: 36, -1: 16, 1: 12})
# VNO accuracy: (-1, 0.328125). Average accuracy:0.3861042583518594
# Data spread:  Counter({'1': 106, '0': 92, '-1': 55})
# accuracy: 0.296875
# predicted class counts: Counter({0: 28, 1: 24, -1: 12})
# VMC accuracy: (-1, 0.296875). Average accuracy:0.38591640728164495
# Data spread:  Counter({'1': 111, '0': 102, '-1': 40})
# accuracy: 0.515625
# predicted class counts: Counter({0: 44, 1: 15, -1: 5})
# WRB accuracy: (0, 0.515625). Average accuracy:0.38618890432517095
# Data spread:  Counter({'1': 112, '-1': 92, '0': 49})
# accuracy: 0.4375
# predicted class counts: Counter({-1: 34, 1: 21, 0: 9})
# WAB accuracy: (1, 0.4375). Average accuracy:0.38629647475635503
# Data spread:  Counter({'1': 103, '0': 99, '-1': 51})
# accuracy: 0.40625
# predicted class counts: Counter({0: 47, 1: 14, -1: 3})
# WMT accuracy: (0, 0.40625). Average accuracy:0.3863382185330154
# Data spread:  Counter({'-1': 97, '1': 78, '0': 78})
# {count} / 500 trained
# accuracy: 0.40625
# predicted class counts: Counter({-1: 38, 1: 18, 0: 8})
# WBA accuracy: (-1, 0.40625). Average accuracy:0.38637978801415734
# Data spread:  Counter({'1': 96, '0': 88, '-1': 69})
# accuracy: 0.328125
# predicted class counts: Counter({0: 44, -1: 11, 1: 9})
# DIS accuracy: (0, 0.328125). Average accuracy:0.3862584238724612
# Data spread:  Counter({'0': 116, '1': 103, '-1': 34})
# accuracy: 0.5
# predicted class counts: Counter({0: 46, 1: 14, -1: 4})
# WM accuracy: (0, 0.5). Average accuracy:0.3864948928456993
# Data spread:  Counter({'1': 112, '-1': 73, '0': 68})
# accuracy: 0.328125
# predicted class counts: Counter({1: 33, -1: 17, 0: 14})
# WAT accuracy: (-1, 0.328125). Average accuracy:0.38637379348294887
# Data spread:  Counter({'1': 123, '0': 89, '-1': 41})
# accuracy: 0.390625
# predicted class counts: Counter({1: 38, 0: 24, -1: 2})
# WEC accuracy: (1, 0.390625). Average accuracy:0.38638259515275647
# Data spread:  Counter({'1': 121, '-1': 69, '0': 63})
# accuracy: 0.34375
# predicted class counts: Counter({1: 38, -1: 17, 0: 9})
# WCG accuracy: (1, 0.34375). Average accuracy:0.38629451127847386
# Data spread:  Counter({'1': 99, '0': 90, '-1': 64})
# accuracy: 0.34375
# predicted class counts: Counter({1: 25, 0: 21, -1: 18})
# WFC accuracy: (-1, 0.34375). Average accuracy:0.3862067906366626
# Data spread:  Counter({'1': 110, '0': 79, '-1': 64})
# accuracy: 0.28125
# predicted class counts: Counter({1: 32, 0: 20, -1: 12})
# WELL accuracy: (1, 0.28125). Average accuracy:0.38599083016210156
# Data spread:  Counter({'1': 123, '-1': 104, '0': 26})
# accuracy: 0.5
# predicted class counts: Counter({1: 42, -1: 21, 0: 1})
# WDC accuracy: (1, 0.5). Average accuracy:0.38622493523363727
# Data spread:  Counter({'1': 125, '0': 84, '-1': 44})
# accuracy: 0.515625
# predicted class counts: Counter({1: 33, 0: 23, -1: 8})
# WU accuracy: (0, 0.515625). Average accuracy:0.3864900993007815
# Data spread:  Counter({'1': 111, '-1': 95, '0': 47})
# {count} / 500 trained
# accuracy: 0.40625
# predicted class counts: Counter({-1: 41, 1: 20, 0: 3})
# WRK accuracy: (-1, 0.40625). Average accuracy:0.3865305080956674
# Data spread:  Counter({'1': 114, '0': 70, '-1': 69})
# accuracy: 0.421875
# predicted class counts: Counter({1: 31, 0: 19, -1: 14})
# WY accuracy: (1, 0.421875). Average accuracy:0.3866026397117987
# Data spread:  Counter({'1': 116, '-1': 82, '0': 55})
# accuracy: 0.484375
# predicted class counts: Counter({1: 35, -1: 23, 0: 6})
# WHR accuracy: (1, 0.484375). Average accuracy:0.38680176875515554
# Data spread:  Counter({'1': 105, '-1': 89, '0': 59})
# accuracy: 0.390625
# predicted class counts: Counter({1: 37, -1: 24, 0: 3})
# WMB accuracy: (-1, 0.390625). Average accuracy:0.3868095395503686
# Data spread:  Counter({'1': 120, '0': 91, '-1': 42})
# accuracy: 0.296875
# predicted class counts: Counter({1: 39, 0: 18, -1: 7})
# WLTW accuracy: (0, 0.296875). Average accuracy:0.38662711654925225
# Data spread:  Counter({'1': 128, '-1': 83, '0': 42})
# accuracy: 0.421875
# predicted class counts: Counter({1: 46, -1: 18})
# WYNN accuracy: (1, 0.421875). Average accuracy:0.38669846854004325
# Data spread:  Counter({'1': 115, '0': 94, '-1': 44})
# accuracy: 0.34375
# predicted class counts: Counter({1: 33, 0: 30, -1: 1})
# XEL accuracy: (0, 0.34375). Average accuracy:0.38661170395713407
# Data spread:  Counter({'1': 119, '-1': 75, '0': 59})
# accuracy: 0.40625
# predicted class counts: Counter({1: 39, -1: 13, 0: 12})
# XRX accuracy: (1, 0.40625). Average accuracy:0.3866512972959302
# Data spread:  Counter({'1': 121, '-1': 84, '0': 48})
# accuracy: 0.34375
# predicted class counts: Counter({1: 35, -1: 20, 0: 9})
# XLNX accuracy: (0, 0.34375). Average accuracy:0.3865649767782321
# Data spread:  Counter({'1': 116, '0': 70, '-1': 67})
# accuracy: 0.453125
# predicted class counts: Counter({1: 34, 0: 15, -1: 15})
# XYL accuracy: (1, 0.453125). Average accuracy:0.38669863144333605
# Data spread:  Counter({'0': 117, '1': 93, '-1': 43})
# {count} / 500 trained
# accuracy: 0.484375
# predicted class counts: Counter({0: 51, 1: 12, -1: 1})
# YUM accuracy: (0, 0.484375). Average accuracy:0.3868943756689005
# Data spread:  Counter({'1': 128, '-1': 76, '0': 49})
# accuracy: 0.421875
# predicted class counts: Counter({1: 47, 0: 12, -1: 5})
# ZBRA accuracy: (1, 0.421875). Average accuracy:0.3869643369175627
# Data spread:  Counter({'1': 115, '0': 78, '-1': 60})
# accuracy: 0.421875
# predicted class counts: Counter({1: 25, 0: 23, -1: 16})
# ZBH accuracy: (1, 0.421875). Average accuracy:0.3870340188798031
# Data spread:  Counter({'1': 109, '-1': 76, '0': 68})
# accuracy: 0.296875
# predicted class counts: Counter({-1: 33, 1: 30, 0: 1})
# ZION accuracy: (1, 0.296875). Average accuracy:0.3868544192406003
# Data spread:  Counter({'1': 119, '0': 86, '-1': 48})
# accuracy: 0.390625
# predicted class counts: Counter({1: 27, 0: 26, -1: 11})
# ZTS accuracy: (1, 0.390625). Average accuracy:0.38686191542501264
